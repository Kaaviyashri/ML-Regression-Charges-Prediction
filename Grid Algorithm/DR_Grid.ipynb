# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype = int, drop_first = True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse'],
              'max_features':[None, 'sqrt', 'log2'],
              'splitter':['best', 'random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,  n_jobs = -1)

grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}:

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.024304      0.002958         0.008695        0.001749
# 1        0.022709      0.008740         0.009504        0.002181
# 2        0.015731      0.002245         0.010403        0.004080
# 3        0.014665      0.002071         0.009196        0.000629
# 4        0.017431      0.001793         0.010553        0.002038
# 5        0.017589      0.002761         0.010298        0.001987
# 6        0.077805      0.003655         0.007555        0.000846
# 7        0.057421      0.004932         0.009836        0.002079
# 8        0.047707      0.005717         0.009298        0.001166
# 9        0.038571      0.003082         0.008872        0.000739
# 10       0.046061      0.002764         0.007914        0.000733
# 11       0.040590      0.004369         0.008327        0.001022
# 12       0.019556      0.002873         0.008246        0.000733
# 13       0.015805      0.002647         0.010427        0.002248
# 14       0.019474      0.002704         0.010892        0.001017
# 15       0.014409      0.001368         0.009301        0.001104
# 16       0.014521      0.002503         0.007565        0.001229
# 17       0.011462      0.001832         0.006036        0.000792
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.719972
# 1   {'criterion': 'squared_error', 'max_features':...           0.692607
# 2   {'criterion': 'squared_error', 'max_features':...           0.745148
# 3   {'criterion': 'squared_error', 'max_features':...           0.610965
# 4   {'criterion': 'squared_error', 'max_features':...           0.640254
# 5   {'criterion': 'squared_error', 'max_features':...           0.680357
# 6   {'criterion': 'absolute_error', 'max_features'...           0.730951
# 7   {'criterion': 'absolute_error', 'max_features'...           0.674756
# 8   {'criterion': 'absolute_error', 'max_features'...           0.739971
# 9   {'criterion': 'absolute_error', 'max_features'...           0.715624
# 10  {'criterion': 'absolute_error', 'max_features'...           0.700337
# 11  {'criterion': 'absolute_error', 'max_features'...           0.603564
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.713057
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.625269
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.644051
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.613822
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.718635
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.686677
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.615683           0.743073           0.727931
# 1            0.644454           0.706995           0.702433
# 2            0.430530           0.686518           0.628220
# 3            0.610457           0.663416           0.739108
# 4            0.612722           0.469820           0.526434
# 5            0.597365           0.713041           0.690570
# 6            0.583709           0.696480           0.715547
# 7            0.594571           0.763486           0.735261
# 8            0.620568           0.604757           0.712205
# 9            0.540957           0.730422           0.709812
# 10           0.611467           0.715368           0.703915
# 11           0.690288           0.640097           0.614887
# 12           0.643875           0.724373           0.739454
# 13           0.587906           0.720844           0.679371
# 14           0.568622           0.722612           0.702312
# 15           0.540260           0.681326           0.593531
# 16           0.624223           0.731525           0.596492
# 17           0.563786           0.605990           0.726882
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.673854         0.696102        0.046371                4
# 1            0.731940         0.695686        0.028712                5
# 2            0.637035         0.625490        0.106012               16
# 3            0.703648         0.665519        0.050758               12
# 4            0.743368         0.598519        0.094535               18
# 5            0.703718         0.677010        0.041352                8
# 6            0.762653         0.697868        0.061055                3
# 7            0.730901         0.699795        0.059968                1
# 8            0.705967         0.676694        0.053753                9
# 9            0.757263         0.690815        0.076704                7
# 10           0.737026         0.693623        0.043029                6
# 11           0.737962         0.657360        0.050153               14
# 12           0.672095         0.698571        0.035326                2
# 13           0.673477         0.657373        0.046105               13
# 14           0.724299         0.672379        0.059469               11
# 15           0.681075         0.622003        0.053978               17
# 16           0.711238         0.676423        0.055034               10
# 17           0.702783         0.657224        0.061888               15

# %%
age_input = float(input("Age: "))
bmi_input = float(input("BMI: "))
children_input = int(input("Children: "))
sex_male_input = int(input("Sex Male - 1 for yes or 0 for no: "))
smoker_yes_input = int(input("Smoke Yes - 1 for yes or 0 for no: "))
# Out:
# Age:  33
# BMI:  34
# Children:  2
# Sex Male - 1 for yes or 0 for no:  1
# Smoke Yes - 1 for yes or 0 for no:  1

# %%
result = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("result = {}".format(result))
# Out:
# result = [37607.5277]
# C:\Users\kaavi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
